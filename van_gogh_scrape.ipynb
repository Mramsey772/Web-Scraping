# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !mkdir /content/gdrive/MyDrive/van_gogh
# Out:
# mkdir: cannot create directory ‘/content/gdrive/MyDrive/van_gogh’: File exists

# %%
import urllib
import re
from bs4 import BeautifulSoup
import time

file_path = "/content/gdrive/MyDrive/van_gogh"
base_url = "https://www.wikiart.org"
painting_url = []


 # get the artist's web page for the artwork
url = "https://www.wikiart.org/en/vincent-van-gogh/all-works/text-list"
artist_work_soup = BeautifulSoup(urllib.request.urlopen(url), "lxml")

image_count = 0


# get the list of artwork
lis = artist_work_soup.find_all("li", class_ ="painting-list-text-row")

# for each list element
for li in lis:
  link = li.find("a")

  if link != None:
    painting = link.attrs["href"]
    painting_url.append(painting)

      # get the painting
    url = base_url + painting
    print(url)

    try:
      painting_soup = BeautifulSoup(urllib.request.urlopen(url), "lxml")
      og_image = painting_soup.find("meta", {"property":"og:image"})
      print(og_image)
      image_url = og_image["content"].split("!")[0] # ignore the !Large.jpg at the end
      print(image_url)

      parts = url.split("/")
      painting_name = parts[-1]
      save_path = file_path + "/" + painting_name + ".jpg"

      try:
        print("downloading to " + save_path)
        time.sleep(0.2)  # try not to get a 403                    
        urllib.request.urlretrieve(image_url, save_path)
        image_count = image_count + 1
      except Exception as e:
        print("failed downloading " + image_url, e) 
      

    except:
      print("error retreiving page")
      continue
# Out:
# Streaming output truncated to the last 5000 lines.
# <meta content="https://uploads1.wikiart.org/images/vincent-van-gogh/worn-out-1882.jpg!Large.jpg" property="og:image"/>
# https://uploads1.wikiart.org/images/vincent-van-gogh/worn-out-1882.jpg
# downloading to /content/gdrive/MyDrive/van_gogh/worn-out-1882.jpg
# https://www.wikiart.org/en/vincent-van-gogh/young-man-with-a-broom-1882
# <meta content="https://uploads6.wikiart.org/images/vincent-van-gogh/young-man-with-a-broom-1882.jpg!Large.jpg" property="og:image"/>
# https://uploads6.wikiart.org/images/vincent-van-gogh/young-man-with-a-broom-1882.jpg
# downloading to /content/gdrive/MyDrive/van_gogh/young-man-with-a-broom-1882.jpg
# https://www.wikiart.org/en/vincent-van-gogh/bridge-near-the-schenkweg
# <meta content="https://uploads7.wikiart.org/images/vincent-van-gogh/bridge-near-the-schenkweg(1).jpg!Large.jpg" property="og:image"/>
# https://uploads7.wikiart.org/images/vincent-van-gogh/bridge-near-the-schenkweg(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/bridge-near-the-schenkweg.jpg
# https://www.wikiart.org/en/vincent-van-gogh/blacksmith-shop
# <meta content="https://uploads6.wikiart.org/images/vincent-van-gogh/blacksmith-shop(1).jpg!Large.jpg" property="og:image"/>
# https://uploads6.wikiart.org/images/vincent-van-gogh/blacksmith-shop(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/blacksmith-shop.jpg
# https://www.wikiart.org/en/vincent-van-gogh/boy-with-cap-and-clogs
# <meta content="https://uploads4.wikiart.org/images/vincent-van-gogh/boy-with-cap-and-clogs(1).jpg!Large.jpg" property="og:image"/>
# https://uploads4.wikiart.org/images/vincent-van-gogh/boy-with-cap-and-clogs(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/boy-with-cap-and-clogs.jpg
# https://www.wikiart.org/en/vincent-van-gogh/boy-with-spade
# <meta content="https://uploads5.wikiart.org/images/vincent-van-gogh/boy-with-spade(1).jpg!Large.jpg" property="og:image"/>
# https://uploads5.wikiart.org/images/vincent-van-gogh/boy-with-spade(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/boy-with-spade.jpg
# https://www.wikiart.org/en/vincent-van-gogh/a-sheet-with-sketches-1883
# <meta content="https://uploads8.wikiart.org/images/vincent-van-gogh/a-sheet-with-sketches-1883(1).jpg!Large.jpg" property="og:image"/>
# https://uploads8.wikiart.org/images/vincent-van-gogh/a-sheet-with-sketches-1883(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/a-sheet-with-sketches-1883.jpg
# https://www.wikiart.org/en/vincent-van-gogh/baby-1
# <meta content="https://uploads6.wikiart.org/images/vincent-van-gogh/baby-1(1).jpg!Large.jpg" property="og:image"/>
# https://uploads6.wikiart.org/images/vincent-van-gogh/baby-1(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/baby-1.jpg
# https://www.wikiart.org/en/vincent-van-gogh/baby-crawling
# <meta content="https://uploads4.wikiart.org/images/vincent-van-gogh/baby-crawling(1).jpg!Large.jpg" property="og:image"/>
# https://uploads4.wikiart.org/images/vincent-van-gogh/baby-crawling(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/baby-crawling.jpg
# https://www.wikiart.org/en/vincent-van-gogh/breakwater-1883
# <meta content="https://uploads6.wikiart.org/images/vincent-van-gogh/breakwater-1883(1).jpg!Large.jpg" property="og:image"/>
# https://uploads6.wikiart.org/images/vincent-van-gogh/breakwater-1883(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/breakwater-1883.jpg
# https://www.wikiart.org/en/vincent-van-gogh/bulb-fields-1883
# <meta content="https://uploads7.wikiart.org/images/vincent-van-gogh/bulb-fields-1883(1).jpg!Large.jpg" property="og:image"/>
# https://uploads7.wikiart.org/images/vincent-van-gogh/bulb-fields-1883(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/bulb-fields-1883.jpg
# https://www.wikiart.org/en/vincent-van-gogh/cemetery-1883
# <meta content="https://uploads4.wikiart.org/images/vincent-van-gogh/cemetery-1883(1).jpg!Large.jpg" property="og:image"/>
# https://uploads4.wikiart.org/images/vincent-van-gogh/cemetery-1883(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/cemetery-1883.jpg
# https://www.wikiart.org/en/vincent-van-gogh/churchyard-in-the-rain-1883
# <meta content="https://uploads0.wikiart.org/images/vincent-van-gogh/churchyard-in-the-rain-1883(1).jpg!Large.jpg" property="og:image"/>
# https://uploads0.wikiart.org/images/vincent-van-gogh/churchyard-in-the-rain-1883(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/churchyard-in-the-rain-1883.jpg
# https://www.wikiart.org/en/vincent-van-gogh/churchyard-in-the-rain-1883-1
# <meta content="https://uploads2.wikiart.org/images/vincent-van-gogh/churchyard-in-the-rain-1883-1(1).jpg!Large.jpg" property="og:image"/>
# https://uploads2.wikiart.org/images/vincent-van-gogh/churchyard-in-the-rain-1883-1(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/churchyard-in-the-rain-1883-1.jpg
# https://www.wikiart.org/en/vincent-van-gogh/churchyard-in-winter-1883
# <meta content="https://uploads7.wikiart.org/images/vincent-van-gogh/churchyard-in-winter-1883(1).jpg!Large.jpg" property="og:image"/>
# https://uploads7.wikiart.org/images/vincent-van-gogh/churchyard-in-winter-1883(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/churchyard-in-winter-1883.jpg
# https://www.wikiart.org/en/vincent-van-gogh/churchyard-in-winter-1883-1
# <meta content="https://uploads0.wikiart.org/images/vincent-van-gogh/churchyard-in-winter-1883-1(1).jpg!Large.jpg" property="og:image"/>
# https://uploads0.wikiart.org/images/vincent-van-gogh/churchyard-in-winter-1883-1(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/churchyard-in-winter-1883-1.jpg
# https://www.wikiart.org/en/vincent-van-gogh/cottages-1883
# <meta content="https://uploads4.wikiart.org/images/vincent-van-gogh/cottages-1883(1).jpg!Large.jpg" property="og:image"/>
# https://uploads4.wikiart.org/images/vincent-van-gogh/cottages-1883(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/cottages-1883.jpg
# https://www.wikiart.org/en/vincent-van-gogh/drawbridge-in-nieuw-amsterdam-1883
# <meta content="https://uploads7.wikiart.org/images/vincent-van-gogh
1889(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/garden-of-the-asylum-and-tree-trunks-and-a-stone-bench-1889.jpg
# https://www.wikiart.org/en/vincent-van-gogh/great-peacock-moth-1889
# <meta content="https://uploads5.wikiart.org/images/vincent-van-gogh/great-peacock-moth-1889(1).jpg!Large.jpg" property="og:image"/>
# https://uploads5.wikiart.org/images/vincent-van-gogh/great-peacock-moth-1889(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/great-peacock-moth-1889.jpg
# https://www.wikiart.org/en/vincent-van-gogh/green-wheat-field-with-cypress-1889-1
# <meta content="https://uploads1.wikiart.org/images/vincent-van-gogh/green-wheat-field-with-cypress-1889-1(1).jpg!Large.jpg" property="og:image"/>
# https://uploads1.wikiart.org/images/vincent-van-gogh/green-wheat-field-with-cypress-1889-1(1).jpg
# downloading to /content/gdrive/MyDrive/van_gogh/green-wheat-field-with-cypress-1889-1.jpg
# https://www.wikiart.org/en/vincent-van-gogh/head-of-an-angel-after-rembrandt-1889
# <meta content="https://uploads7.wikiart.org/images/vincent-van-gogh/head-of-an-angel-after-rembrandt-1889.jpg!Large.jpg" property="og:image"/>
# https://uploads7.wikiart.org/images/vincent-van-gogh/head-of-an-angel-after-rembrandt-1889.jpg
# downloading to /content/gdrive/MyDrive/van_gogh/head-of-an-angel-after-rembrandt-1889.jpg
# https://www.wikiart.org/en/vincent-van-gogh/irises-1889
# <meta content="https://uploads0.wikiart.org/00213/images/vincent-van-gogh/antique-3840759.jpg!Large.jpg" property="og:image"/>
# https://uploads0.wikiart.org/00213/images/vincent-van-gogh/antique-3840759.jpg
# downloading to /content/gdrive/MyDrive/van_gogh/irises-1889.jpg
# https://www.wikiart.org/en/vincent-van-gogh/joseph-etienne-roulin-1889
# <meta content="https://uploads0.wikiart.org/00213/images/vincent-van-gogh/antique-3840760.jpg!Large.jpg" property="og:image"/>
# https://uploads0.wikiart.org/00213/images/vincent-van-gogh/antique-3840760.jpg
# downloading to /content/gdrive/MyDrive/van_gogh/joseph-etienne-roulin-1889.jpg
# https://www.wikiart.org/en/vincent-van-gogh/landscape-with-house-and-ploughman-1889

# %%
print(og_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3c708cda4e1f> in <module>()
# ----> 1 print(og_image)
#
# NameError: name 'og_image' is not defined

# %%
for url in painting_url:
  print(url)
  painting_soup = BeautifulSoup(urllib.request.urlopen(url), "lxml")
  og_image = painting_soup.find("img", {"property":"og:image"})
  print(og_image)
  image_url = og_image["content"].split("!")[0] # ignore the !Large.jpg at the end
  print(image_url)

  parts = url.split("/")
  painting_name = parts[-1]
  save_path = file_path + "/" + painting_name + ".jpg"

                #download the file
  try:
    print("downloading to " + save_path)
    time.sleep(0.2)  # try not to get a 403                    
    urllib.request.urlretrieve(image_url, save_path)
    image_count = image_count + 1
  except Exception as e:
    print("failed downloading " + image_url, e)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a85d8146e827> in <module>()
#       1
# ----> 2 for url in painting_url:
#       3   print(url)
#       4   painting_soup = BeautifulSoup(urllib.request.urlopen(url), "lxml")
#       5   og_image = painting_soup.find("img", {"property":"og:image"})
#
# NameError: name 'painting_url' is not defined

# %%
print(painting_soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <!-- Google Tag Manager -->
# <script>
#     (function (w, d, s, l, i) {
#         w[l] = w[l] || []; w[l].push({
#             'gtm.start':
#                 new Date().getTime(), event: 'gtm.js'
#         }); var f = d.getElementsByTagName(s)[0],
#             j = d.createElement(s), dl = l != 'dataLayer' ? '&l=' + l : ''; j.async = true; j.src =
#                 'https://www.googletagmanager.com/gtm.js?id=' + i + dl; f.parentNode.insertBefore(j, f);
#         })(window, document, 'script', 'dataLayer', 'GTM-P53MQNQ');</script>
# <!-- End Google Tag Manager -->
# <title>Field of Grass with Dandelions and Tree Trunks, 1890 - Vincent van Gogh - WikiArt.org</title>
# <link href="https://www.wikiart.org/en/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks" rel="canonical"/>
# <link href="//uploads.wikiart.org/" rel="dns-prefetch"/>
# <link href="//uploads.wikiart.org" rel="dns-prefetch"/>
# <link href="//uploads0.wikiart.org" rel="dns-prefetch"/>
# <link href="//uploads1.wikiart.org" rel="dns-prefetch"/>
# <link href="//uploads2.wikiart.org" rel="dns-prefetch"/>
# <link href="//uploads3.wikiart.org" rel="dns-prefetch"/>
# <link href="//uploads4.wikiart.org" rel="dns-prefetch"/>
# <link href="//uploads5.wikiart.org" rel="dns-prefetch"/>
# <link href="//uploads6.wikiart.org" rel="dns-prefetch"/>
# <link href="//uploads7.wikiart.org" rel="dns-prefetch"/>
# <!-- meta -->
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="on" http-equiv="cleartype"/>
# <meta content="index, follow" name="robots"/>
# <meta content="‘Field of Grass with Dandelions and Tree Trunks’ was created in 1890 by Vincent van Gogh in Post-Impressionism style. Find more prominent pieces of sketch and study at Wikiart.org – best visual art database." name="description"/>
# <!-- open graph -->
# <meta content="https://www.wikiart.org/en/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks" property="og:url"/>
# <meta content="Field of Grass with Dandelions and Tree Trunks, 1890 - Vincent van Gogh - WikiArt.org" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://uploads1.wikiart.org/images/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks(1).jpg!Large.jpg" property="og:image"/>
# <meta content="750" property="og:image:width"/>
# <meta content="371" property="og:image:height"/>
# <meta content="www.wikiart.org" property="og:site_name"/>
# <meta content="‘Field of Grass with Dandelions and Tree Trunks’ was created in 1890 by Vincent van Gogh in Post-Impressionism style. Find more prominent pieces of sketch and study at Wikiart.org – best visual art database." property="og:description"/>
# <meta content="1038592866179110" property="fb:app_id"/>
# <!-- twitter -->
# <meta content="https://www.wikiart.org/en/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks" name="twitter:site"/>
# <meta content="‘Field of Grass with Dandelions and Tree Trunks’ was created in 1890 by Vincent van Gogh in Post-Impressionism style. Find more prominent pieces of sketch and study at Wikiart.org – best visual art database." name="twitter:description"/>
# <meta content="https://uploads1.wikiart.org/images/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks(1).jpg!Large.jpg" name="twitter:image:src"/>
# <meta content="www.wikiart.org" name="twitter:domain"/>
# <!-- fav icon -->
# <link href="/Content/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/Content/images/favicon.ico" rel="icon" type="image/x-icon"/>
# <!-- styles -->
# <link href="/Content/css/bundle_beta_frontend?v=dr5nO5iByV5PqnjIr_LF2Y4PWXsRKCc62zItQSg0hO81" rel="stylesheet"/>
# <!-- fonts -->
# <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,700|Roboto+Condensed:400,700&amp;subset=cyrillic,cyrillic-ext" rel="stylesheet"/>
# <!-- hreflang -->
# <link href="https://www.wikiart.org/de/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks" hreflang="de" rel="alternate"/>
# <link href="https://www.wikiart.org/es/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks" hreflang="es" rel="alternate"/>
# <link href="https://www.wikiart.org/fr/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks" hreflang="fr" rel="alternate"/>
# <link href="https://www.wikiart.org/pt/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks" hreflang="pt" rel="alternate"/>
# <link href="https://www.wikiart.org/ru/vinsent-van-gog/field-of-grass-with-dandelions-and-tree-trunks" hreflang="ru" rel="alternate"/>
# <link href="https://www.wikiart.org/uk/vinsent-van-gog/field-of-grass-with-dandelions-and-tree-trunks" hreflang="uk" rel="alternate"/>
# <link href="https://www.wikiart.org/zh/wen-sen-te-fan-gao/field-of-grass-with-dandelions-and-tree-trunks" hreflang="zh" rel="alternate"/>
# <script type="application/ld+json">
#         {
#         "@context": "https://schema.org",
#         "@type": "WebSite",
#         "url": "https://www.wikiart.org/",
#         "potentialAction": {
#         "@type": "SearchAction",
#         "target": "https://www.wikiart.org/en/search/{search_term_string}",
#         "query-input": "required name=search_term_string"
#         }
#         }
#     </script>
# </head>
# <body ng-app="v2wiki-app-beta" ng-controller="FrontendCtrl" ng-init="initLanguages(&quot;en&quot;, [{ &quot;TwoWordName&quot; : &quot;en&quot;, &quot;Name&quot; : &quot;English&quot; }, { &quot;TwoWordName&quot; : &quot;bg&quot;, &quot;Name&quot; : &quot;Bulgarian&quot; }, { &quot;TwoWordName&quot; : &quot;ca&quot;, &quot;Name&quot; : &quot;Català&quot; }, { &quot;TwoWordName&quot; : &quot;cs&quot;, &quot;Name&quot; : &quot;Čeština&quot; }, { &quot;TwoWordName&quot; : &quot;da&quot;, &quot;Name&quot; : &quot;Dansk&quot; }, { &quot;TwoWordName&quot; : &quot;de&quot;, &quot;Name&quot; : &quot;Deutsch&quot; },
ordName&quot; : &quot;nl&quot;, &quot;Name&quot; : &quot;Dutch&quot; }, { &quot;TwoWordName&quot; : &quot;es&quot;, &quot;Name&quot; : &quot;Español&quot; }, { &quot;TwoWordName&quot; : &quot;fr&quot;, &quot;Name&quot; : &quot;Française&quot; }, { &quot;TwoWordName&quot; : &quot;id&quot;, &quot;Name&quot; : &quot;Indonesian&quot; }, { &quot;TwoWordName&quot; : &quot;it&quot;, &quot;Name&quot; : &quot;Italian&quot; }, { &quot;TwoWordName&quot; : &quot;hu&quot;, &quot;Name&quot; : &quot;Magyar&quot; }, { &quot;TwoWordName&quot; : &quot;no&quot;, &quot;Name&quot; : &quot;Norsk&quot; }, { &quot;TwoWordName&quot; : &quot;pl&quot;, &quot;Name&quot; : &quot;Polski&quot; }, { &quot;TwoWordName&quot; : &quot;pt&quot;, &quot;Name&quot; : &quot;Portuguese&quot; }, { &quot;TwoWordName&quot; : &qu ...
# <!-- Google Tag Manager (noscript) -->
# <noscript>
# <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-P53MQNQ" style="display:none;visibility:hidden" width="0"></iframe>
# </noscript>
# <!-- End Google Tag Manager (noscript) -->
# <script id="loginPopup.html" type="text/ng-template">
#         <div ng-switch="formNameToShow" >
#             <div ng-switch-default ng-controller="SignInModalCtrl" name="loginFormContainer" class="loginFormContainer animated">
#                 <div class="modal-header">
#                     <h1 class="modal-header-title">Sign In</h1><div class="modal-header-close" ng-click="cancel()">&#215</div>
#                 </div>
#                 <div class="modal-body">
#                     <form name="loginPopupForm">
#                         <div ng-messages="validationModel" class="validationSummary validationAnimation" ng-if="showValidationSummary(validationModel)">
#                             <div ng-message="login" class="error">
#                                 {{validationModel['login']}}
#                             </div>
#                             <div ng-message="password_match_exception" class="error">
#                                 {{validationModel['password_match_exception']}}
#                             </div>
#                             <div ng-message="state" class="error">
#                                 {{validationModel['state']}}
#                             </div>
#                             <div ng-message="password" class="error">
#                                 {{validationModel['password']}}
#                             </div>
#                         </div>
#
#                             <div class="modal-input" >
#                                 <input type="text" name="email" ng-model="email" ng-pattern="emailFormat" was-focused required ng-change="validationModel = {};" ng-class="(loginPopupForm.email.$invalid && loginPopupForm.email.wasFocused) ? 'validationError' : ''" placeholder="E-mail *" >
#                                 <div class="messages validationAnimation" ng-messages="loginPopupForm.email.$error" ng-if="loginPopupForm.email.wasFocused === true" >
#                                     <div ng-message="required" class="validationError">
#                                         E-mail is required
#                                     </div>
#                                     <div ng-message="pattern" class="validationError">
#                                        Wrong e-mail format
#                                     </div>
#                                 </div>
#                             </div>
#
#                             <div class="modal-input">
#                                 <input type="password" name="password" ng-model="password" on-enter-pressed="login();" was-focused ng-change="validationModel = {};" required ng-class="(loginPopupForm.password.$invalid && loginPopupForm.password.wasFocused) ? 'validationError' : ''" placeholder="Password *">
#                                 <div class="messages validationAnimation" ng-messages="loginPopupForm.password.$error" ng-if="loginPopupForm.password.wasFocused">
#                                     <div ng-message="required" class="validationError">
#                                         Password is required
#                                     </div>
#                                 </div>
#                             </div>
#
#                             <div class="forgotPassword">
#                                 <a ng-click="showRestorePassword();">Forgot password?</a>
#                             </div>
#
#                             <input type="button" class="button-light loginButton" ng-click="login();" value="Sign In" />
#
#                             <div class="terms-of-use">
#                                 <span>By signing in, you agree to our</span> <a target="_blank" href="/{{$parent.currentLanguage}}/terms-of-use">Terms of Use</a>
#                             </div>
# </form>
#                     <div class="separator">
#                         <span class="line">
#                             <span class="text">
#                                 or sign in with
#                             </span>
#                         </span>
#                     </div>
#                     <form role="form" method="POST" action="/en/App/WikiAccountBeta/ExternalLogin?ReturnUrl=/en/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks">
#                         <input name="__RequestVerificationToken" type="hidden" value="NnUY2KuOOzeKpYjG37kxikcCvC3kfsUoOFBf9cz8wm8j7c-Ip0eKY9bPWJS_943wwITiJUCjAEuie3pfc_VEDvSp6PlcJJH_IZPKz0y-Y5LBtdTiI59TfNkXTOb1kfJgz2Jwog2" />
#                         <div class="socialButtonsContainer">
#                             <button type="submit" name="provider" value="facebook" class="button-light fbButton" />
#                             <button type="submit" name="provider" value="google" class="button-light gmailButton" />
#                         </div>
#                     </form>
#
#                     <div class="registerLink">
#                         Don&#39;t have an account?
#                         <a ng-click="showRegister();"> Sign up</a>.
#                     </div>
#
#
#                 </div>
#             </div>
#             <div ng-switch-when="register" class="registerFormContainer animated" ng-controller="SignUpModalCtrl">
#                 <div class="modal-header">
#                     <h1 class="modal-header-title">Sign up</h1><div class="modal-header-close" ng-click="cancel()">&#215</div>
#                 </div>
#                 <div class="modal-body">
#                     <form name="registerPopupForm">
#                         <div ng-messages="validationModel" class="validationSummary validationAnimation" ng-if="showValidationSummary(validationModel)">
#                             <div ng-message="login" class="error">
#                                 {{validationModel['login']}}
#                             </div>
#                             <div ng-message="password" class="error">
#                                 {{validationModel['password']}}
#                             </div>
#                         </div>
#
#                         <div class="modal-input">
#                             <input type="text" name="email" ng-model="email" ng-pattern="emailFormat" was-focused required ng-change="validationModel = {};" ng-class="(registerPopupForm.email.$invalid && registerPopupForm.email.wasFocused) ? 'validationError' : ''" placeholder="E-mail *" >
#                             <div class="messages validationAnimation" ng-messages="registerPopupForm.email.$error" ng-if="registerPopupForm.email.wasFocused">
#                                 <div ng-message="required" class="validationError">
#                                     E-mail is required
#                                 </div>
#                                 <div ng-message="pattern" class="validationError">
#                                     Wrong e-mail format
#                                 </div>
#                             </div>
#                         </div>
#
#
#                         <div class="passwordContainer">
#                             <div class="modal-input password">
#                                 <input type="password" name="password" ng-change="validationModel = {};" was-focused ng-model="password" required ng-class="(registerPopupForm.password.$invalid && registerPopupForm.password.wasFocused) ? 'validationError' : ''" placeholder="Password *" >
#                                 <div class="messages validationAnimation" ng-messages="registerPopupForm.password.$error" ng-if="registerPopupForm.password.wasFocused">
#                                     <div ng-message="required" class="validationError">
#                                         Password is required
#                                     </div>
#                                 </div>
#                             </div>
#                             <div class="modal-input confirmPassword">
#                                 <input type="password" name="confirmPassword" ng-change="validationModel = {};" was-focused ng-model="confirmPassword" required ng-class="(registerPopupForm.confirmPassword.$invalid && registerPopupForm.confirmPassword.wasFocused) ? 'validationError' : ''" placeholder="Confirm *">
#                                 <div class="messages validationAnimation" ng-messages="registerPopupForm.confirmPassword.$error" ng-if="registerPopupForm.confirmPassword.wasFocused">
#                                     <div ng-message="required" class="validationError">
#                                         Password is required
#                                     </div>
#                                 </div>
#                             </div>
#                         </div>
#
#                         <input type="button" class="button-light signUpButton" ng-click="register()" value="Create Account" />
#
#                         <div class="terms-of-use">
#                             <span>By signing up, you agree to our</span> <a target="_blank" href="javascript:;" ng-href="/{{$parent.currentLanguage}}/terms-of-use">Terms of Use</a>
#                         </div>
#                     </form>
#                     <div class="separator">
#                         <span class="line">
#                             <span class="text">
#                                 or sign up with
#                             </span>
#                         </span>
#                     </div>
#                     <form role="form" method="POST" action="/en/App/WikiAccountBeta/ExternalLogin?ReturnUrl=/en/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks">
#                         <input name="__RequestVerificationToken" type="hidden" value="Y3PEAqMkoG2KPfxdwoTv75smm8jCgd3MsFJw_J7GoxVw7INhQgBYGc6lFB1swKSlW3xAhx6FcVAgj7yc52EhZ1V-nzh2IRC0cicyhSTpPQSRyFk0cfLKienYQ2VAqSHKSOavoQ2" />
#                         <div class="socialButtonsContainer">
#                             <button type="submit" name="provider" value="facebook" class="button-light fbButton" />
#                             <button type="submit" name="provider" value="google" class="button-light gmailButton" />
#                         </div>
#                     </form>
#
#                     <div class="loginLink">
#                         Already have an account?
#                         <a ng-click="showLogin();"> Sign In</a>.
#                     </div>
#                 </div>
#             </div>
#
#             <div ng-switch-when="restorePassword" class="restorePasswordFormContainer animated" ng-controller="RestorePasswordModalCtrl">
#                 <div class="modal-header">
#                     <h1 class="modal-header-title">Restore password</h1><div class="modal-header-close" ng-click="cancel()">&#215</div>
#                 </div>
#                 <div class="modal-body">
#                     <form name="restorePasswordPopupForm">
#
#                         <div ng-messages="validationModel" class="validationSummary validationAnimation" ng-if="showValidationSummary(validationModel)" >
#                             <div ng-message="login" class="error">
#                                 {{validationModel['login']}}
#                             </div>
#                         </div>
#
#                         <div class="modal-input restoreEmail">
#                             <input type="text" name="email" ng-model="email" ng-pattern="emailFormat" ng-change="validationModel = {};" was-focused on-enter-pressed="restorePassword();" required ng-class="(restorePasswordPopupForm.email.$invalid && restorePasswordPopupForm.email.wasFocused) ? 'validationError' : ''" placeholder="E-mail *">
#                             <div class="messages validationAnimation" ng-messages="restorePasswordPopupForm.email.$error" ng-if="restorePasswordPopupForm.email.wasFocused">
#                                 <div ng-message="required" class="validationError">
#                                     E-mail is required
#                                 </div>
#                                 <div ng-message="pattern" class="validationError">
#                                     Wrong e-mail format
#                                 </div>
#                             </div>
#                         </div>
#
#                         <input type="button" class="button-light restorePasswordButton" ng-click="restorePassword()" value="Submit" />
#                     </form>
#                 </div>
#             </div>
#
#             <div ng-switch-when="createPassword" class="createPasswordFormContainer" ng-controller="CreatePasswordModalCtrl">
#                 <div class="modal-header">
#                     <h1 class="modal-header-title">Create password</h1><div class="modal-header-close" ng-click="cancel()">&#215</div>
#                 </div>
#                 <div class="modal-body">
#                     <form name="createPasswordPopupForm">
#
#                         <div ng-messages="validationModel" class="validationSummary validationAnimation" ng-if="showValidationSummary(validationModel)">
#                             <div ng-message="password" class="error">
#                                 {{validationModel['password']}}
#                             </div>
#                         </div>
#
#                         <div class="passwordContainer">
#                             <div class="modal-input password">
#                                 <input type="password" name="password" ng-change="validationModel = {};" was-focused ng-model="password" required ng-class="(createPasswordPopupForm.password.$invalid && createPasswordPopupForm.password.wasFocused) ? 'validationError' : ''" placeholder="Password *">
#                                 <div class="messages validationAnimation" ng-messages="createPasswordPopupForm.password.$error" ng-if="createPasswordPopupForm.password.wasFocused">
#                                     <div ng-message="required" class="validationError">
#                                         Password is required
#                                     </div>
#                                 </div>
#                             </div>
#                             <div class="modal-input confirmPassword">
#                                 <input type="password" name="confirmPassword" ng-change="validationModel = {};" was-focused ng-model="confirmPassword" required ng-class="(createPasswordPopupForm.confirmPassword.$invalid && createPasswordPopupForm.confirmPassword.wasFocused) ? 'validationError' : ''" placeholder="Confirm *">
#                                 <div class="messages validationAnimation" ng-messages="createPasswordPopupForm.confirmPassword.$error" ng-if="createPasswordPopupForm.confirmPassword.wasFocused">
#                                     <div ng-message="required" class="validationError">
#                                         Password is required
#                                     </div>
#                                 </div>
#                             </div>
#
#                         </div>
#
#                         <input type="button" class="button-light createPasswordButton" ng-click="createPassword()" value="Submit" />
#                     </form>
#                 </div>
#             </div>
#
#             <div ng-switch-when="displayName" class="displayNameFormContainer" ng-controller="DisplayNameModalCtrl">
#                 <div class="modal-header">
#                     <h1 class="modal-header-title">One last step...</h1><div class="modal-header-close" ng-click="cancel()">&#215</div>
#                 </div>
#                 <div class="modal-body">
#                     <form name="displayNamePopupForm">
#                         <div ng-messages="validationModel" class="validationSummary validationAnimation" ng-if="showValidationSummary(validationModel)">
#                             <div ng-message="DisplayName" class="error">
#                                 {{validationModel['DisplayName']}}
#                             </div>
#                         </div>
#                         <div class="small-header">Tell us more about yourself</div>
#                         <div class="modal-input">
#                             <label></label>
#                             <input type="text" name="displayName" on-enter-pressed="saveDisplayName();" ng-change="validationModel = {};" ng-model="displayName" was-focused ng-class="(displayNamePopupForm.displayName.$invalid && displayNamePopupForm.displayName.wasFocused) ? 'validationError' : ''" placeholder="Display name *" >
#
#                         </div>
#                         <input type="button" class="button-light saveDisplayNameButton" ng-click="saveDisplayName()" value="Submit" />
#                         <span class="hint">Your display name will be visible to all users on Recent Changes and Action History pages. You cannot change your display name.</span>
#                     </form>
#                 </div>
#             </div>
#
#             <div ng-switch-when="message" class="messageContainer animated">
#                 <div class="modal-header">
#                     <h1 class="modal-header-title" dynamic-html="modalMessage.Header"></h1><div class="modal-header-close" ng-click="cancel()">&#215</div>
#                 </div>
#                 <div class="modal-body">
#                     <span class="message" dynamic-html="modalMessage.Text">
#                     </span>
#                     <span class="hint" dynamic-html="modalMessage.Hint">
#                     </span>
#                 </div>
#             </div>
#         </div>
#     </script>
# <script id="SupersizedView.cshtml" type="text/ng-template">
#
# <div id="supersized-container" ng-class="{'fade-controls': mouseStopped}">
#     <div class="supersized-debugger" style="display: none;">
#         <div>Max Zoom = {{hmr.maxZoom}}</div>
#         <div>Heigth = {{model.currentImage.height}}</div>
#         <div>Width = {{model.currentImage.width}}</div>
#     </div>
#     <div class="sueprsized-navigation-left"><a class="sueprsized-navigation-fullscreen-prev" hm-tap="swipeHandler('prev')"></a></div>
#     <div class="sueprsized-navigation-fullscreen-top"></div>
#     <div class="sueprsized-navigation-fullscreen-bottom"></div>
#     <div class="overlay-panel" ng-show="hmr.currentMoves.pinch">
#         <strong>{{100 * (hmr.transform[0] / hmr.maxZoom) | number:0}}%</strong>
#     </div>
#     <ul ng-show="imageVariantsVisible" class="supersized-variants-container" ng-class="{'open': imageVariantsOpen, 'animate': imageVariantsOpenAnimation}">
#         <li class="controls">
#             <a class="supersized-navigation-variants-arrow" ng-if="model.artwork.images" hm-tap="toggleImageVariants()"></a>
#             <a class="supersized-navigation-variants" ng-if="model.artwork.images" hm-tap="toggleImageVariants()" ng-class="{'open': scope.imageVariantsOpen}">{{model.artwork.images.length + 1}}</a>
#         </li>
#         <li ng-class="model.variantIndex == -1 ? 'selected' : ''" style="background-image: url('{{imageVariantUrl(model.artwork.image)}}')" ng-click="$root.$broadcast('supersized-variant', {index: -1})"></li>
#         <li ng-class="model.variantIndex == $index ? 'selected' : ''" ng-repeat="img in model.artwork.images" style="background-image: url('{{imageVariantUrl(img.image)}}')" ng-click="$root.$broadcast('supersized-variant', {index: $index})"></li>
#     </ul>
#     <div class="supersized-content">
#         <div class="size-debugger" ng-show="showDebugger">
#             <table>
#                 <thead>
#                     <t>
#                 <td>Image</td>
#                 <td>Size</td>
#                 <td>State</td>
#                 </t>
#                 </thead>
#                 <tbody>
#                     <tr ng-repeat="(k, v) in imagesPreloader">
#                         <td>{{v.name}}</td>
#                         <td>{{imageSizeService.getSizeName(k)}}</td>
#                         <td>{{v.state}}</td>
#                     </tr>
#                 </tbody>
#             </table>
#             <div class="debugger-flags">
#                 <div class="debugger-flag" ng-repeat="(k, v) in cfg.PAINTING_FOR_GALLERY_FLAGS" ng-class="{'active': flagIsChecked(model.artwork.flags, v)}">
#                     {{k}}
#                 </div>
#             </div>
#             <a ng-click="hideDebugger()">Close</a>
#         </div>
#         <a class="hidden-blank"
#            ng-click="selfRedirectToOrderReprodution()">
#             <div class="supersized-slide-wrapper" ng-class="{'grab': grabCursor(), 'pointer': pointerCursor()}"
#                  ng-swipe-left="swipeleft()"
#                  ng-swipe-right="swiperight()"
#                  hm-panstart="panstart($event)"
#                  hm-panmove="panmove($event)"
#                  hm-panend="panend($event)"
#                  hm-pinchstart="pinchstart($event)"
#                  hm-pinchmove="pinchmove($event)"
#                  hm-pinchend="pinchend($event)"
#                  hm-doubletap="doubletap($event)"
#                  hm-tap="tap($event)"
#                  hm-recognizer-options='[{"type":"tap", event: "doubletap", "enable":true,"taps":2,"time":500,"interval":250,"threshold":10,"posThreshold":200}]'>
#                 <img class="primary-image" ng-class="{'loading' : model.loading }" /><div class="loader" ng-class="{'visible' : originalIsLoading && zoomChanged }"></div>
#                 <div class="copyright-message" ng-if="showCopyrightText()" ng-bind="buildCopyrightText()"></div>
#                 <div><img class="animation-helper"></div>
#                 <div class="sueprsized-overlay-artwork-info" ng-class="{'hidden': !artworkInfoPanelVisible }">
#                     <div ng-if="model.artwork.images && imageVariantsVisible" class="sueprsized-overlay-artwork-variants">
#                         <div class="sueprsized-overlay-artwork-variants-item"
#                              ng-class="model.variantIndex == -1 ? 'selected' : ''"
#                              style="background-image: url('{{model.artwork.image}}!PinterestSmall.{{model.artwork.image.substr(model.artwork.image.lastIndexOf('.') + 1)}}')"
#                              hm-tap="overlayImageVariantClick($event, -1)">
#                         </div>
#                         <div class="sueprsized-overlay-artwork-variants-item"
#                              ng-class="model.variantIndex == $index ? 'selected' : ''"
#                              ng-repeat="img in model.artwork.images"
#                              style="background-image: url('{{img.image}}!PinterestSmall.{{img.image.substr(img.image.lastIndexOf('.') + 1)}}')"
#                              hm-tap="overlayImageVariantClick($event, $index)"></div>
#                     </div>
#                     <div class="artist-title">
#                         <h3>{{model.artwork.artistName}}</h3><em>{{model.position + 1}}/{{model.total}}</em>
#                     </div>
#                     <div class="artwork-title"><h2>{{model.artwork.title}}</h2></div>
#                 </div>
#             </div>
#         </a>
#     </div>
#     <div class="sueprsized-navigation-bottom" style="touch-action: manipulation;">
#         <div class="sueprsized-navigation-panel-left">
#             <a target="_self" ng-href="{{paintingUrl()}}" class="supersized-slide-details-link"></a>
#             <div class="supersized-slide-header-wrapper">
#                 <a target="_self" class="supersized-slide-header" ng-href="{{artistUrl()}}" title="{{model.artwork.artistName}}">{{model.artwork.artistName}}</a>
#                 <a class="supersized-slide-text">{{model.position + 1}} / {{model.total}}</a>
#                 <a class="supersized-slide-name" title="{{model.artwork.title}}">{{model.artwork.title}} <span class="year">({{model.artwork.year}})</span></a>
#             </div>        </div>
#         <div class="sueprsized-navigation-panel-center">
#             <a class="supersized-btn-prev" ng-class="{'disabled': !navigationEnabled() }" hm-tap="swipeHandler('prev')"><i></i></a>
#             <a ng-class="{'supersized-btn-pause': model.slideshow, 'supersized-btn-play': !model.slideshow, 'disabled': !navigationEnabled() }" hm-tap="model.toggleSlideshow()"><i></i></a>
#             <a class="supersized-btn-next" ng-class="{'disabled': !navigationEnabled() }" hm-tap="swipeHandler('next')"><i></i></a>
#         </div>
#         <div class="sueprsized-navigation-panel-right">
#             <a class="supersized-social-folder" hm-tap="albums()" ng-class="{'active': fav.IsInAnyAlbum(model.artwork.id || model.artwork._id)}" hm-tap="albums()"></a>
#             <a class="supersized-social-like" ng-class="{'active': fav.IsFavoured(model.artwork.id), 'in-progress': favouriteInProgress}" hm-tap="like()">
#                 <i class="icon-spin4 animate-spin loader"></i>
#             </a>
#             <a target="_blank" ng-show="model.showBestPriceArtLink(model.artwork)" ng-click="redirectToOrderReprudution()" class="supersized-social-cart hidden-blank"></a>
#         </div>
#         <div ng-show="model.showDetails" class="sueprsized-navigation-panel-details">
#             <a class="sueprsized-navigation-panel-details-album" ng-class="{'active': fav.IsInAnyAlbum(model.artwork.id)}" hm-tap="albums()">Add to album<i class="sueprsized-navigation-panel-details-arrow"></i></a>
#             <a class="sueprsized-navigation-panel-details-like" ng-class="{'active': fav.IsFavoured(model.artwork.id), 'in-progress': favouriteInProgress}" hm-tap="like()"><span class="icon-spin4 animate-spin"></span>Add to favourites</a>
#             <a target="_blank" class="sueprsized-navigation-panel-details-order hidden-blank" hm-tap="redirectToOrderReprudution()" ng-show="model.showBestPriceArtLink(model.artwork)">Order reproduction</a>
#             <a class="sueprsized-navigation-panel-details-info" hm-tap="redirectToInfoPage($event)">Artwork page</a>
#         </div>
#         <div ng-cloak class="sueprsized-navigation-panel-small" ng-class="model.showDetails ? 'sueprsized-navigation-panel-small-active' : ''">
#             <a class="supersized-small-more" hm-tap="toggleDetails()"><i></i></a>
#             <a class="supersized-small-zoom"
#                hm-tap="manualZoom();"
#                ng-show="zoomEnabled()"
#                ng-class="hmr.transform[0] > 1 ? 'zoom-out' : 'zoom-in'"><i></i></a>
#             <a class="supersized-small-close"
#                hm-tap="hide($event)"><i></i></a>
#         </div>
#     </div>
#     <div class="sueprsized-navigation-right">
#         <a class="sueprsized-navigation-fullscreen-next" hm-tap="swipeHandler('next')"></a>
#         <a class="sueprsized-navigation-close" hm-tap="hide($event)"></a>
#         <a class="supersized-navigation-fullscreen" hm-tap="toggleFullscreen($event)" ng-class="{'disabled': !fullscreenSupported() }"></a>
#         <a class="supersized-navigation-zoom-in" ng-class="{'disabled': !canZoomIn()}" ng-show="zoomEnabled()" hm-tap="incZoom()"></a>
#         <a class="supersized-navigation-zoom-slider-bar" ng-show="zoomEnabled()"></a>
#         <a class="supersized-navigation-zoom-slider-position" ng-show="zoomEnabled()" ng-style="{top: sliderPosition() + 'px'}"></a>
#         <a class="supersized-navigation-zoom-out" ng-class="{'disabled': !canZoomOut()}" ng-show="zoomEnabled()" hm-tap="decZoom()"></a>
#     </div>
# </div>
# </script>
# <div ng-controller="SupersizedCtrl" ng-init="copyrightMsg = 'Artworks of {0} are not available in your country on copyright grounds.'; init();"><supersized-view model="supersized"></supersized-view></div>
# <div class="wiki-container ">
# <section class="wiki-top-menu-mobile">
# <a class="close" onclick="toggleMobileMenu(this)"></a>
# <div></div>
# <div class="languages" ng-init='selectedLanguage = { "TwoWordName" : "en", "Name" : "English" }'>
# <span class="selectedLanguage">{{selectedLanguage.Name}}</span>
# <select ng-change="languageChanged(selectedLanguage)" ng-model="selectedLanguage" ng-options="language as language.Name for language in localizedLanguages track by language.TwoWordName"></select>
# </div>
# <a class="auth" ng-click="showAuthModal('login');" ng-if="!isLoggedIn"><span>Sign In</span></a>
# <a class="auth" ng-click="logOut();" ng-if="isLoggedIn"><span>Sign out</span></a>
# </section>
# <header>
# <nav class="wiki-top-menu" ng-cloak="">
# <div class="wiki-top-menu-logo-container">
# <a class="pixel-icon" href="https://www.wikiart.org/en/claude-monet/boaters-at-argenteuil" style="background: url('https://uploads4.wikiart.org/00186/images/pixel-icons/monet-boaters-at-argenteuil.jpg') no-repeat center center #fff; background-size: 50px 50px; " target="_self"></a>
# <a class="wiki-top-menu-logo en" href="/" target="_self">
# </a>
# </div>
# <a class="wiki-top-menu-mobile-switch" href="javascript:;" onclick="toggleMobileMenu(this)" outside-if-not="wiki-left-menu">
# </a>
# <form action="" class="wiki-top-menu-search-wrapper" click-outside="findElementAndRemoveClass('search-input-active');">
# <a class="wiki-top-menu-search-textbox">
# <input placeholder="Search" type="text"/>
# <div class="wiki-top-menu-search-icon"></div>
# <ul class="wiki-top-menu-search-result"></ul>
# </a>
# <a class="wiki-top-menu-search-logo en" href="/" target="_self">
# </a>
# <a class="wiki-top-menu-search" href="javascript:;" onclick="toggleSearch(this)"></a>
# </form>
# <div class="wiki-top-menu-lang-wrapper" click-outside="findElementAndRemoveClass('lang-input-active');">
# <a class="wiki-top-menu-lang" data-current-lang="en" href="javascript:;" onclick="toggleLanguage(this)">
# <b>en</b>
# </a>
# <ul class="wiki-top-menu-lang-list" ng-cloak="">
# <li><a class="language-link" href="/de/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks"><h6>Deutsch</h6></a></li>
# <li><a class="language-link" href="/es/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks"><h6>Español</h6></a></li>
# <li><a class="language-link" href="/fr/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks"><h6>Française</h6></a></li>
# <li><a class="language-link" href="/pt/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks"><h6>Portuguese</h6></a></li>
# <li><a class="language-link" href="/ru/vinsent-van-gog/field-of-grass-with-dandelions-and-tree-trunks"><h6>Русский</h6></a></li>
# <li><a class="language-link" href="/uk/vinsent-van-gog/field-of-grass-with-dandelions-and-tree-trunks"><h6>Українська</h6></a></li>
# <li><a class="language-link" href="/zh/wen-sen-te-fan-gao/field-of-grass-with-dandelions-and-tree-trunks"><h6>中文</h6></a></li>
# </ul>
# </div>
# <a class="wiki-top-menu-auth" href="javascript:;" ng-click="showAuthModal('login');">
# <b>Sign In {{}} </b>
# </a>
# </nav>
# </header>
# <div class="wiki-container-responsive ">
# <div class="actions-menu" ng-cloak="" ng-controller="PaintingActionMenuCtrl" ng-show="actionMenuIsOpened">
# <div class="actions-menu-right">
# <a class="action-menu-navigation right " href="/en/edit/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks">Edit</a>
# <a class="action-menu-navigation right " href="/en/translate/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks">Translate</a>
# <a class="action-menu-navigation right " href="/en/actionhistory/viewbydocumentid/5772712fedc2cb3880c0cb6c">Action History</a>
# </div>
# </div>
# <div class="beta-top-message-wrapper ">
# <div class="beta-top-message">
# </div>
# <div class="beta-top-message-close" onclick="closeTopMessage()">×</div>
# </div>
# <div class="beta-go-to-top hidden" ng-class="{'anonymous': !currentUser}"></div>
# <script id="MasonryView.cshtml" type="text/ng-template">
#     <li data-id="{{::artwork.id}}"
#     ng-repeat="artwork in artworks track by $index"
#     ng-style="{'left' : artwork.left + 'px', 'top' : artwork.top + 'px', width : options.columnWidth + 'px', margin: options.columnMargin + 'px'}"
#     ng-class="{ 'overlay': artwork.hover, 'deleted': $parent.options.showDeleteFromAlbumBtn && !isInAlbum($parent.options.albumId, paintingJson._id || paintingJson.id)}"
#     style="position:absolute;-webkit-transition-delay:{{($index % 10 + 1) * 75}}ms; "
#     ng-controller="FavouritesCtrl" ng-init="paintingJson = $parent.artwork; init();" >
#     <div ng-if="DEBUG" style="position: absolute; top: 10px; left: 50%; color: #fff; background: #000;">#{{$index}}</div>
#     <div class="supersized-hover-container"></div>
#     <img ng-class="{'blur': isRestricted(artwork.flags)}" src="https://uploads.wikiart.org/Content/wiki/img/lazy-load-placeholder.png" class="lazy-load" ng-click="onSlideClick(artwork, $index, options)" lazy-load img-source="imageUrl(artwork, options.imageFormat)" ng-style="{'width' : options.columnWidth + 'px', 'height' : artwork.height * (options.columnWidth / artwork.width) + 'px', 'cursor': 'pointer'}" title="{{artwork.title}} - {{artwork.artistName}}" alt="{{artwork.title}} - {{artwork.artistName}}"/>
#     <div class="title-block" id="title-block-{{::artwork.id}}">
#         <div class="like-overlay like-overlay-left">
#             <a ng-show="isLoggedIn() && !$parent.options.showDeleteFromAlbumBtn" ng-class="isFavoured(paintingJson._id || paintingJson.id) ? 'favoured' : ''" favourites favourites-status="paintingJson.isLiked" favourites-id="paintingJson._id || paintingJson.id">
#                 <i class="icon-spin4 animate-spin"></i>
#             </a>
#             <a album ng-show="isLoggedIn() && $parent.options.showDeleteFromAlbumBtn"
#                 ng-class="isInAlbum($parent.options.albumId, paintingJson._id || paintingJson.id) ? 'delete' : 'deleted'"
#                 albums-list="paintingJson.albums" album-id="$parent.options.albumId"
#                 album-painting-id="paintingJson._id || paintingJson.id">
#                 <i class="icon-spin4 animate-spin"></i>
#             </a>
#             <a ng-show="!isLoggedIn()" ng-click="$root.showAuthModal('login', null, favourWithRedirectUrl(paintingJson.paintingUrl, paintingJson._id))" targe="_self"></a>
#         </div>
#         <div class="like-overlay like-overlay-zoom like-overlay-right">
#             <a ng-click="$root.$broadcast('supersized-start', {index: $index, options: options})"></a>
#         </div>
#         <a target="_self" href="{{::artwork.paintingUrl}}" class="artwork-name">{{artwork.title}} {{currentLanguage}}</a>
#         <a target="_self" href="{{::artwork.artistUrl}}" class="artist-name">
#             {{::artwork.artistName}}&nbsp;•&nbsp;
#             <span class="artwork-year">{{::artwork.year}}</span>
#         </a>
#     </div>
# </li>
#
# </script>
# <script id="CarouselView.cshtml" type="text/ng-template">
#
#         <main style="animation: {{containerAnimation}}">
#         <ul style="width: {{totalWidth}}px; transition: transform 500ms ease; transform: translate3d({{scroll}}px, 0, 0)">
#         <li ng-repeat="a in artworks" style="width: {{a.actualWidth}}px">
#              <a target="_self" href="{{a.paintingUrl}}">
#                  <img src="{{a.image}}!Large.{{a.image.substr(a.image.lastIndexOf('.') + 1)}}" />
#             </a>
#             <div class="artist-related-title">
#                 <h5>
#                     <a target="_self" href="{{a.paintingUrl}}">{{a.title}}</a>
#                     <span class="separator">&nbsp;&bullet;&nbsp;</span>
#                     <span class="artwork-year">{{a.year}}</span>
#                 </h5>
#             </div>
#         </li>
#         </ul>
#         </main>
# </script>
# <script id="ViewAllSizesPopup.cshtml" type="text/ng-template">
#     <div class="modal-header">
#     <div class="modal-header-title">Thumbnail sizes</div><div class="modal-header-close" ng-click="cancel()">&#215</div>
# </div>
# <div class="modal-body view-thumnails-sizes-container editing-scrollbar">
#     <div class="view-thumnails-sizes-item" ng-repeat="model in thumbnailSizesModel.ImageThumbnailsModel">
#         <div class="image-container">
#             <img ng-src="{{model.IllustrationUrl}}" />
#         </div>
#         <div class="thumbnails-container">
#             <div class="thumbnail-item" ng-repeat="thumbnail in model.Thumbnails">
#                 <a target="_blank" class="hidden-blank" href="{{thumbnail.Url}}">{{thumbnail.Width}}x{{thumbnail.Height}}</a> <span ng-show="thumbnail.SizeKB !== 0">, {{thumbnail.SizeKB}} KB</span> <span ng-show="thumbnail.Name === 'Original'">(original)</span>
#             </div>
#         </div>
#
#     </div>
# </div>
#
# </script>
# <script id="copyrightNotesPopup.html" type="text/ng-template">
#         <div class="loginFormContainer copyright-notes-popup">
#             <div class="modal-header">
#                 <div class="modal-header-title" ng-switch on="copyrightType">
#                     <span ng-switch-when="1">Copyright Information</span>
#                     <span ng-switch-when="2">Copyright Information</span>
#                     <span ng-switch-when="6">Copyright Information</span>
#                     <span ng-switch-when="3">Copyright Information</span>
#                     <span ng-switch-when="4">Copyright Information</span>
#                     <span ng-switch-when="5">Copyright Information</span>
#                     <span ng-switch-when="-1">Copyright Information</span>
#                     <span ng-switch-when="-10">Copyright Information</span>
#                     <span ng-switch-when="-20">Copyright Information</span>
#                 </div>
#                 <div class="modal-header-close" ng-click="cancel()">&#215</div>
#             </div>
#             <div class="modal-body" ng-switch on="copyrightType">
#                 <div ng-switch-when="1">
#                     <p>
#                         This artwork is in public domain in its country of origin and other countries and areas where the copyright term is the author&#39;s life plus 70 years or less. If you are a copyright owner of this artwork, or his/hers legal representative, and you do not agree that this artwork is public domain, please let us know wikipaintings@gmail.com
#                         <br /><br />
#                         WikiArt.org allows unlimited copying, distributing and displaying of the images of public domain artworks. Artworks protected by copyright are supposed to be used only for contemplation. Images of that type of artworks are prohibited for copying, printing, or any kind of reproducing and communicating to public since these activities may be considered copyright infringement.
#                     </p>
#                 </div>
#                 <div ng-switch-when="2">
#                     <p>
#                         This artwork is in the public domain in the United States because it was published before January 1, 1923. If you are a copyright owner of this artwork, or his/hers legal representative, and you do not agree that this artwork is public domain, please let us know wikipaintings@gmail.com
#                         <br /><br />
# ...
# </div>
# </li>
# <li style="width: 246.274311694872px">
# <a href="/en/vincent-van-gogh/the-starry-night-1889" target="_self"><img alt="The Starry Night - Vincent van Gogh" class="image-rendering-fix lazy-load" img-source="'https://uploads4.wikiart.org/00142/images/vincent-van-gogh/the-starry-night.jpg!Large.jpg'" lazy-load="" src="https://uploads.wikiart.org/Content/wiki/img/lazy-load-placeholder.png" title="The Starry Night - Vincent van Gogh"/></a>
# <div class="artist-related-title">
# <h5 precision-px="10" suffix="…" truncate=""><a class="truncate-target" href="/en/vincent-van-gogh/the-starry-night-1889" target="_self" title="The Starry Night">The Starry Night</a><span class="separator"> &amp;bullet; </span><span class="artwork-year">1889</span></h5>
# </div>
# </li>
# <li style="width: 165.814855875831px">
# <a href="/en/vincent-van-gogh/portrait-of-doctor-gachet-1890" target="_self"><img alt="Portrait of Doctor Gachet - Vincent van Gogh" class="image-rendering-fix lazy-load" img-source="'https://uploads0.wikiart.org/images/vincent-van-gogh/portrait-of-doctor-gachet-1890.jpg!Large.jpg'" lazy-load="" src="https://uploads.wikiart.org/Content/wiki/img/lazy-load-placeholder.png" title="Portrait of Doctor Gachet - Vincent van Gogh"/></a>
# <div class="artist-related-title">
# <h5 precision-px="10" suffix="…" truncate=""><a class="truncate-target" href="/en/vincent-van-gogh/portrait-of-doctor-gachet-1890" target="_self" title="Portrait of Doctor Gachet">Portrait of Doctor Gachet</a><span class="separator"> &amp;bullet; </span><span class="artwork-year">1890</span></h5>
# </div>
# </li>
# <li style="width: 155.133333333333px">
# <a href="/en/vincent-van-gogh/prisoners-exercising-prisoners-round-1890" target="_self"><img alt="Prisoners Exercising (Prisoners Round) - Vincent van Gogh" class="image-rendering-fix lazy-load" img-source="'https://uploads2.wikiart.org/images/vincent-van-gogh/prisoners-exercising-prisoners-round-1890.jpg!Large.jpg'" lazy-load="" src="https://uploads.wikiart.org/Content/wiki/img/lazy-load-placeholder.png" title="Prisoners Exercising (Prisoners Round) - Vincent van Gogh"/></a>
# <div class="artist-related-title">
# <h5 precision-px="10" suffix="…" truncate=""><a class="truncate-target" href="/en/vincent-van-gogh/prisoners-exercising-prisoners-round-1890" target="_self" title="Prisoners Exercising (Prisoners Round)">Prisoners Exercising (Prisoners Round)</a><span class="separator"> &amp;bullet; </span><span class="artwork-year">1890</span></h5>
# </div>
# </li>
# <li style="width: 402.103448275862px">
# <a href="/en/vincent-van-gogh/wheatfield-with-crows-1890" target="_self"><img alt="Wheatfield with Crows - Vincent van Gogh" class="image-rendering-fix lazy-load" img-source="'https://uploads5.wikiart.org/images/vincent-van-gogh/wheatfield-with-crows-1890.jpg!Large.jpg'" lazy-load="" src="https://uploads.wikiart.org/Content/wiki/img/lazy-load-placeholder.png" title="Wheatfield with Crows - Vincent van Gogh"/></a>
# <div class="artist-related-title">
# <h5 precision-px="10" suffix="…" truncate=""><a class="truncate-target" href="/en/vincent-van-gogh/wheatfield-with-crows-1890" target="_self" title="Wheatfield with Crows">Wheatfield with Crows</a><span class="separator"> &amp;bullet; </span><span class="artwork-year">1890</span></h5>
# </div>
# </li>
# <li class="all-works-square" style="width: 203px">
# <a href="/en/vincent-van-gogh/all-works" target="_self">
# </a>
# <h6 class="all-works-square-text" style="pointer-events: none;">
#                 View all 1931 artworks
#             </h6>
# </li>
# </ul>
# </main>
# </div>
# </section>
# <section class="wiki-layout-artworks-famous">
# <div class="wiki-section-header-wrapper wiki-section-header-wrapper-related">
# <div class="wiki-section-header" data-fittext="" data-fittext-depends-on="famous" data-fittext-force-line-height="normal" data-fittext-id="related" data-fittext-max="31" data-fittext-min="20" div="" style="position: relative;">
# <span>Related Artworks</span>
# <span class="info-circle-related wiki-hover-panel-parent" data-popup-body="Unless handpicked by an editor, related artworks are generated automatically. They are chosen by proximity in style, genre, tags, and date of creation." data-popup-title="Related Artworks" ng-click="showGeographicalNotesModal(null, $event)"></span>
# </div>
# </div>
# <main>
# <div ng-cloak="" ng-controller="MasonryCtrl" ng-init="options = {'masonryId' : 'related-artworks', 'filter' : {'UniqueName' : 'related', 'Url' : '/en/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks?json=2'},'resultType' : 'masonry',
#                           'fitParams' : {
#                             'over1200' : { 'columns' : 5, 'columnMargin' : 10, 'columnWidth' : 220 },
#                             'over999' :  { 'columns' : 4, 'columnMargin' : 10, 'columnWidth' : 220 },
#                             'over759' :  { 'columns' : 3, 'columnMargin' : 10, 'columnWidth' : 220 },
#                             'over479' :  { 'columns' : 2, 'columnMargin' : 10, 'columnWidth' : 200 },
#                             'over320' :  { 'columns' : 2, 'columnMargin' : 10, 'columnWidth' : null }
#                            }, 'imageFormat' : 'PinterestSmall' }; init();">
# <div class="masonry-content" ng-switch="options.resultType">
# <div ng-switch-when="masonry">
# <ul class="wiki-masonry-container" masonry-items="paintingsToDisplay" masonry-options="options" masonry-view="">
# </ul>
# </div>
# <div class="wiki-detailed-container" ng-switch-when="detailed">
# <div class="wiki-detailed-item-container" dynamic-html="paintingHtml" dynamic-html-position="{{$index}}" dynamic-html-total="{{paintingsToDisplay.length}}" ng-repeat="paintingHtml in paintingsToDisplay" ng-style="{'-webkit-transition-delay' : '{{($index % 10 + 1) * 150}}ms'}"></div>
# </div>
# <div class="masonry-text-view" ng-switch-when="text">
# <div dynamic-html="paintingsHtml"></div>
# </div>
# </div>
# <!-- <div supersized-view model="supersized"></div> -->
# <div class="masonry-load-more-button-wrapper">
# <a class="masonry-load-more-button" ng-click="loadMore();" ng-show="canLoadMore()">
# <span class="count">1-{{getCurrentCount()}} out of {{getTotalCount()}}</span>
# <span class="loadmore-icon" ng-class="(ajaxLoading) ? 'rotation' : ''"></span> <span class="load-more-phrase">LOAD MORE</span>
# </a>
# </div>
# </div>
# </main>
# </section>
# <div class="short-of-the-month-section view-painting-section">
# <header>
# <h1 data-fittext="" data-fittext-max="31" data-fittext-min="14">
#                 Court Métrage
#             </h1>
# <span class="header-tip">Short Films</span>
# </header>
# <div class="main-info movie-section">
# <aside>
# <div class="video-block__wrapper" style="padding-top: 54.05%">
# <a class="video-block__thumbnail-wrapper" href="/en/app/court-metrage/brotherhood">
# <img alt="Brotherhood [2018]" class="lazy-load video-block__thumbnail" img-source="'https://i.vimeocdn.com/video/846297217_1280x720.jpg?r=pad'" lazy-load="" src="https://uploads.wikiart.org/Content/wiki/img/lazy-load-placeholder.png" title="Brotherhood [2018]"/>
# </a>
# </div>
# <div class="video-block__description">
#                     Added: 21 Dec, 2020
#                 </div>
# </aside>
# <article>
# <div class="overflowing-container" is-overflowing-bind="showShadow" max-height-values="maxHeightValues" ng-init="showShadow = false; maxHeightValues={'widthOver1239': 570 * 0.5405,
#                     'widthOver759': 430 * 0.5405,
#                     'widthBelow760': 250}" overflowing="">
# <h3><a href="/en/app/court-metrage/brotherhood" target="_self">Brotherhood [2018]</a></h3>
# <ul>
# <li>
# <s>Directed by:</s>
# <span>
# <a href="javascript:;" style="pointer-events:none; color:black;" target="_self">Meryam Joobeur</a>
# </span>
# </li>
# <li>
# <s>Written by:</s>
# <span>
# <a href="javascript:;" style="pointer-events:none; color:black;" target="_self">Meryam Joobeur</a>
# </span>
# </li>
# <li>
# <s>Produced by:</s>
# <span>
# <a href="javascript:;" style="pointer-events:none; color:black;" target="_self">Maria Gracia Turgeon</a>,        <a href="javascript:;" style="pointer-events:none; color:black;" target="_self">Habib Attia</a>
# </span>
# </li>
# <li>
#                             Mohamed is deeply shaken when his oldest son Malik returns home after a long journey with a mysterious new wife.
#                         </li>
# </ul>
# <div class="text-shadow-container" ng-show="showShadow"></div>
# </div>
# <div class="go-to-movie">
# <a href="/en/app/court-metrage/brotherhood" target="_self">Watch now</a>
# </div>
# </article>
# </div>
# </div>
# </div>
# <div class="wiki-footer-wrapper-dark">
# <div class="wiki-container-responsive">
# <script id="subscribeSuccessful.html" type="text/ng-template">
#     <div class="loginFormContainer">
#         <div class="modal-header">
#             <div class="modal-header-title">
#                 Succesfully subscribed
#             </div>
#             <div class="modal-header-close" ng-click="cancel()">&#215</div>
#         </div>
#         <div class="modal-body" style="position: absolute; bottom: 40%; line-height: 1.5; padding-left: 25px; padding-right: 25px;">
#             <div> You have been successfully subscribed to our newsletters.</div>
#         </div>
#         <div class="modal-footer">
#             <div class="buttons-block">
#                 <div class="save-album-button" style="float: left;" ng-click="cancel()">Ok</div>
#             </div>
#         </div>
#     </div>
# </script>
# <footer class="wiki-footer" ng-class="{'anonymous': !isLoggedIn}">
# <ul class="wiki-footer-column-logo">
# <div class="logo-wrapper">
# <a class="pixel-icon" href="https://www.wikiart.org/en/claude-monet/boaters-at-argenteuil" style="background: url('https://uploads4.wikiart.org/00186/images/pixel-icons/monet-boaters-at-argenteuil.jpg') no-repeat center center #fff; background-size: 50px 50px;" target="_self">
# </a>
# <a class="logo en" href="/" target="_self"></a>
# <a class="social-fb hidden-blank" href="https://www.facebook.com/wikiart.org" target="_blank"></a>
# <a class="social-twitter hidden-blank" href="https://twitter.com/wikipaintings" target="_blank"></a>
# </div>
# <div ng-if="!isLoggedIn"> <div ng-cloak="" ng-controller="SubscribeCtrl" ng-init="formName = 'formDesktop'">
# <form class="form-subscribe" name="formDesktop" ng-submit="submit()" novalidate="">
# <div class="header">
# <div class="label" ng-if="!terms || !getForm().email.wasFocused || getForm().$valid">Signup for news &amp; updates</div>
# <div class="messages" ng-if="terms &amp;&amp; getForm().email.wasFocused === true" ng-messages="getForm().email.$error">
# <div class="validationError" ng-message="pattern">
#                         You entered the wrong email.
#                     </div>
# </div>
# </div>
# <div class="submit">
# <input name="email" ng-change="validationModel = {};" ng-class="{'invalid' : terms &amp;&amp; (getForm().email.$invalid &amp;&amp; getForm().email.wasFocused === true)}" ng-model="email" ng-pattern="regexpEmail" placeholder="Enter your email" type="text" was-focused=""/>
# <input ng-class="{'active': terms &amp;&amp; getForm().email.$$rawModelValue}" type="submit" value="ok"/>
# </div>
# <div class="footer">
# <div class="checkbox" ng-class="{'checked' : terms}" ng-click="toggleTerms()"></div>
# <div class="checkbox-label">
# <span>I agree to</span> <a class="terms-link" ng-href="/{{currentLanguage}}/terms-of-use" target="_blank">terms and conditions</a>
# </div>
# </div>
# </form>
# </div>
# </div>
# </ul>
# <div class="wiki-footer-responsive-wrapper">
# <ul class="wiki-footer-column-links artists">
# <li><h5>Artists</h5></li>
# <li><a href="/en/Alphabet/a" target="_self">A-Z Listing</a></li>
# <li><a href="/en/artists-by-art-movement" target="_self">Art movements</a></li>
# <li><a href="/en/artists-by-painting-school" target="_self">Schools and groups</a></li>
# <li><a href="/en/artists-by-genre" target="_self">Genres</a></li>
# <li><a href="/en/artists-by-field" target="_self">Fields</a></li>
# <li><a href="/en/artists-by-nation" target="_self">Nationalities</a></li>
# <li><a href="/en/artistadvancedsearch" target="_self">Advanced search</a></li>
# <li><a class="hidden-blank order" href="https://www.1st-art-gallery.com/" target="_blank">Purchase a reproduction</a></li>
# <li><a href="/en/artists-by-art-institution" target="_self">Art institutions</a></li>
# <li><a href="/en/chronological-artists" target="_self">Chronology</a></li>
# <li><a href="/en/popular-artists" target="_self">Popular</a></li>
# <li><a href="/en/female-artists" target="_self">Female artists ♀</a></li>
# <li><a href="/en/recently-added-artists" target="_self">Recently added</a></li>
# <li><a href="/en/artists-by-century" target="_self">Centuries</a></li>
# </ul>
# <div class="wiki-footer-responsive-artworks-about-wrapper">
# <ul class="wiki-footer-column-links artworks">
# <li><h5>Artworks</h5></li>
# <li><a href="/en/paintings-by-style" target="_self">Styles</a></li>
# <li><a href="/en/paintings-by-genre" target="_self">Genres</a></li>
# <li><a href="/en/paintings-by-media" target="_self">Media</a></li>
# <li><a href="/en/recently-added-artworks" target="_self">Recently added</a></li>
# <li><a href="/en/popular-paintings/alltime" target="_self">Popular artworks</a></li>
# <li><a href="/en/App/Painting/random" target="_self">Random artwork</a></li>
# <li><a href="/en/paintingadvancedsearch" target="_self">Advanced search</a></li>
# <li><a href="/en/high-resolution-artworks" target="_self">High resolution</a></li>
# </ul>
# <div class="wiki-footer-responsive-about-wrapper">
# <ul class="wiki-footer-column-links court-metrage">
# <li><a href="/en/app/court-metrage" target="_self">Court Métrage<span class="link-arrow"></span></a></li>
# </ul>
# <ul class="wiki-footer-column-links shop">
# <li><a class="hidden-blank" href="https://www.1st-art-gallery.com/" target="_blank">Shop<span class="link-arrow"></span></a></li>
# </ul>
# <ul class="wiki-footer-column-links about">
# <li><h5>About Wikiart</h5></li>
# <li><a href="/en/about" target="_self">About</a></li>
# <li><a class="hidden-blank" href="https://wikiart.uservoice.com" target="_blank">Feedback</a></li>
# <li><a class="donate" href="/en/How-to-Contribute" target="_self">How to contribute</a></li>
# <li><a href="/en/terms-of-use" target="_self">Terms of use</a></li>
# <li><a href="/en/privacy-policy" target="_self">Privacy Policy</a></li>
# <li class="application"><span>Applications</span><a class="application-icon ios hidden-blank" href="https://itunes.apple.com/us/app/wikiart/id1235995167" target="_blank"></a><a class="application-icon android hidden-blank" href="https://play.google.com/store/apps/details?id=com.ilit.wikipaintings" target="_blank"></a> </li>
# <li class="social">
# <a class="share-icon-fb hidden-blank" href="https://www.facebook.com/wikiart.org" target="_blank"><i class="icon-facebook"></i></a>
# <a class="share-icon-twitter hidden-blank" href="https://twitter.com/wikipaintings" target="_blank"><i class="icon-twitter"></i></a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </footer>
# </div>
# </div>
# </div>
# <script src="/bundle/v2wiki-app-beta/js/any?v=WvKNovM1vYSmNqZcIup4AGwWkuwqudjJy2ek94OdmFc1"></script>
# <script defer="">
#                 var url = '/en/App/Home/MarkHasCss/1';
#                 var xmlhttp = new XMLHttpRequest();
#                 xmlhttp.onreadystatechange = function() {
#                     if (xmlhttp.readyState === XMLHttpRequest.DONE) {
#                         if (xmlhttp.status === 200) {
#
#                         } else {
#                             console.error('update of css version has failed');
#                         }
#                     }
#                 };
#                 console.log('css verios cookie request ' + url);
#                 xmlhttp.open("GET", url, true);
#                 xmlhttp.send();
#         </script>
# <script>
#
#     LocalizationService.getInstance().AddLabel("Wikipainting.Search.SearchFor", 'search for');
#     LocalizationService.getInstance().AddLabel("Wikipainting.Artist.Tabs.More", 'More');
#     LocalizationService.getInstance().AddLabel("Wikipainting.Artist.Tabs.Less", 'Less');
#
#     </script>
# <script defer="" src="https://player.vimeo.com/api/player.js"></script>
# </body>
# </html>

# %%
print(painting_url[:5])
#print(len(painting_url))
#print(lis)

#def find_and_parse_URL(url):
 #   result = requests.get(url)
 #   soup = BeautifulSoup(result.text, 'html.parser')
 #   return soup

#for painting in painting_url:
 # new_url = base_url + painting_url[0]
 # new_soup = find_and_parse_URL(new_url)
 # link_2 = find_all
# Out:
# ['/en/vincent-van-gogh/the-goat-herd-1862', '/en/vincent-van-gogh/dog', '/en/vincent-van-gogh/milk-jug', '/en/vincent-van-gogh/the-bridge', '/en/vincent-van-gogh/corinthian-capital-1863']

# %%
for link in (painting_url):
    og_image = painting_soup.findAll("meta")#, {"property":"og:image"})
    image_url = og_image["content"].split("!")[0] # ignore the !Large.jpg at the end
    print(image_url)

    parts = url.split("/")
    painting_name = parts[-1]
    save_path = file_path + "/" + painting_name + ".jpg"

                #download the file
    try:
      print("downloading to " + save_path)
      time.sleep(0.2)  # try not to get a 403                    
      urllib.request.urlretrieve(image_url, save_path)
      image_count = image_count + 1
    except Exception as e:
      print("failed downloading " + image_url, e)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-48c770ddc7a1> in <module>()
#       1 for link in (painting_url):
#       2     og_image = painting_soup.findAll("meta")#, {"property":"og:image"})
# ----> 3     image_url = og_image["content"].split("!")[0] # ignore the !Large.jpg at the end
#       4     print(image_url)
#       5
#
# TypeError: list indices must be integers or slices, not str

# %%
print(og_image)
# Out:
# [<meta charset="utf-8"/>, <meta content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=0" name="viewport"/>, <meta content="IE=edge" http-equiv="X-UA-Compatible"/>, <meta content="on" http-equiv="cleartype"/>, <meta content="index, follow" name="robots"/>, <meta content="‘Field of Grass with Dandelions and Tree Trunks’ was created in 1890 by Vincent van Gogh in Post-Impressionism style. Find more prominent pieces of sketch and study at Wikiart.org – best visual art database." name="description"/>, <meta content="https://www.wikiart.org/en/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks" property="og:url"/>, <meta content="Field of Grass with Dandelions and Tree Trunks, 1890 - Vincent van Gogh - WikiArt.org" property="og:title"/>, <meta content="website" property="og:type"/>, <meta content="https://uploads1.wikiart.org/images/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks(1).jpg!Large.jpg" property="og:image"/>, <meta content="750" property="og:image:width"/>, <meta content="371" property="og:image:height"/>, <meta content="www.wikiart.org" property="og:site_name"/>, <meta content="‘Field of Grass with Dandelions and Tree Trunks’ was created in 1890 by Vincent van Gogh in Post-Impressionism style. Find more prominent pieces of sketch and study at Wikiart.org – best visual art database." property="og:description"/>, <meta content="1038592866179110" property="fb:app_id"/>, <meta content="https://www.wikiart.org/en/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks" name="twitter:site"/>, <meta content="‘Field of Grass with Dandelions and Tree Trunks’ was created in 1890 by Vincent van Gogh in Post-Impressionism style. Find more prominent pieces of sketch and study at Wikiart.org – best visual art database." name="twitter:description"/>, <meta content="https://uploads1.wikiart.org/images/vincent-van-gogh/field-of-grass-with-dandelions-and-tree-trunks(1).jpg!Large.jpg" name="twitter:image:src"/>, <meta content="www.wikiart.org" name="twitter:domain"/>, <meta content="https://en.wikipedia.org/wiki/Vincent_van_Gogh" itemprop="sameAs"/>]

# %% [markdown]
# print(og_image)
